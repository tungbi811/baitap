# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def sigmoid(z):
    return 1/(1+np.exp(-z))

# %%
X = np.linspace(-10,10,1000)
plt.plot(X,sigmoid(X),'-r')
plt.plot([0,0,0],np.linspace(0,1,3),"black")
plt.show()
