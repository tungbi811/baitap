# %%
from cProfile import label
from turtle import position
import numpy as np
import matplotlib.pyplot as plt

months = np.arange(1,13)
profit_A = np.random.randint(400,500,12)
profit_B = np.random.randint(400,500,12)
profit_C = np.random.randint(400,500,12)
profit_D = np.random.randint(400,500,12)
plt.figure(1)
print(profit_A)
print(profit_B)
plt.plot(months,profit_A,'r')
plt.plot(months,profit_B,'b')
plt.legend(['Company A','Company B'],loc='upper left')

plt.figure(2)
plt.subplot(221)
plt.xlabel("Company A")
plt.plot(months,profit_A,'r')
plt.subplot(222)
plt.xlabel("Company B")
plt.plot(months,profit_B,'r')
plt.subplot(223)
plt.plot(months,profit_C,'r')
plt.xlabel("Company C")
plt.subplot(224)
plt.plot(months,profit_D,'r')
plt.xlabel("Company D")

plt.show()
# Out:
# [416 415 432 418 432 456 409 491 480 466 401 469]
# [429 433 417 457 434 418 450 470 475 466 450 403]
