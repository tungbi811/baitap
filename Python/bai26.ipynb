# %%
import numpy as np
import matplotlib.pyplot as plt

months = np.arange(1,13)
profit = np.random.randint(400,500,size=(12,))

plt.plot(months,profit,'r')
plt.xlabel("month")
plt.ylabel("profit")
plt.show()
